# %%
from textblob import TextBlob

# %%
reviews = [
    "I love this product, it is amazing!",
    "This is the worst purchase I ever made.",
    "The product is okay, not great."
]

# %%
for review in reviews:
  blob = TextBlob(review)
  polarity = blob.sentiment.polarity
  if polarity > 0:
    sentiment = "positive"
  elif polarity < 0:
    sentiment = "Negative"
  else:
    sentiment = "Neutral"
  print(f"Review: {review}/nSentiment: {sentiment}/nPolarity: {polarity}/n)")
# Out:
# Review: I love this product, it is amazing!/nSentiment: positive/nPolarity: 0.625/n)
# Review: This is the worst purchase I ever made./nSentiment: Negative/nPolarity: -1.0/n)
# Review: The product is okay, not great./nSentiment: positive/nPolarity: 0.04999999999999999/n)
