# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('pnnkt_tab')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Error loading pnnkt_tab: Package 'pnnkt_tab' not found in
# [nltk_data]     index
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
sentence = "Natural Language processing helps computers understand human "

# %%
tokens = word_tokenize(sentence)

# %%
tags = pos_tag(tokens)
print("pos Tags:", tags)
# Out:
# pos Tags: [('Natural', 'JJ'), ('Language', 'NNP'), ('processing', 'NN'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'VBP'), ('human', 'JJ')]
